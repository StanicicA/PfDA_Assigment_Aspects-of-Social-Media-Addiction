# %% [markdown]
# # Generic Food

# %%
 # Database of 900 common Foods being analysed using CSV File and the folowing
    
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ![Picture of Food](https://www.realsimple.com/thmb/mp_03UKKId3Rcz7ErkxNZvVgS8M=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/non-perishable-emergency-food-natural-disaster-pandemic-epidemic-eb5d2e877e8f494591b83ad5529cc108.jpg)

# %%
#Imported CSV File for analysing Generic Food
pd.read_csv("https://raw.githubusercontent.com/SlobodaStudio/food-nlp/master/generic-food.csv")
# Out:
#            FOOD NAME                                    SCIENTIFIC NAME  \
# 0           Angelica                                   Angelica keiskei
# 1      Savoy cabbage                     Brassica oleracea var. sabauda
# 2      Silver linden                                     Tilia argentea
# 3               Kiwi                                Actinidia chinensis
# 4     Allium (Onion)                                             Allium
# ..               ...                                                ...
# 901    White cabbage  Brassica oleracea L. var. capitata L. f. alba DC.
# 902  Romaine lettuce                  Lactuca sativa L. var. longifolia
# 903        dumplings                                                NaN
# 904           muesli                                                NaN
# 905             milk                                                NaN
#
#                 GROUP                SUB GROUP
# 0    Herbs and Spices                    Herbs
# 1          Vegetables                 Cabbages
# 2    Herbs and Spices                    Herbs
# 3              Fruits          Tropical fruits
# 4          Vegetables  Onion-family vegetables
# ..                ...                      ...
# 901        Vegetables                 Cabbages
# 902        Vegetables          Leaf vegetables
# 903               NaN                      NaN
# 904               NaN                      NaN
# 905               NaN                      NaN
#
# [906 rows x 4 columns]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/SlobodaStudio/food-nlp/master/generic-food.csv")
# There are 4 columns in total: Name, Scientific name, Group, Sub-group. To see the quantity of each, see below
basicstat = (df.describe())
print (basicstat)
# Out:
#        FOOD NAME  SCIENTIFIC NAME          GROUP SUB GROUP
# count        906              648            903       903
# unique       906              639             24       123
# top     Angelica  Capsicum annuum  Aquatic foods    Fishes
# freq           1                6            166       111

# %%
# types of Groups_First four rows for the column Group 
df ['GROUP'][1:5]
# Out:
# 1          Vegetables
# 2    Herbs and Spices
# 3              Fruits
# 4          Vegetables
# Name: GROUP, dtype: object

# %%
#in more detail on the variables
info = df.info ()
print (info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 906 entries, 0 to 905
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FOOD NAME        906 non-null    object
#  1   SCIENTIFIC NAME  648 non-null    object
#  2   GROUP            903 non-null    object
#  3   SUB GROUP        903 non-null    object
# dtypes: object(4)
# memory usage: 28.4+ KB
# None

# %%
#food vs group types
df[['FOOD NAME','GROUP']]
# Out:
#            FOOD NAME             GROUP
# 0           Angelica  Herbs and Spices
# 1      Savoy cabbage        Vegetables
# 2      Silver linden  Herbs and Spices
# 3               Kiwi            Fruits
# 4     Allium (Onion)        Vegetables
# ..               ...               ...
# 901    White cabbage        Vegetables
# 902  Romaine lettuce        Vegetables
# 903        dumplings               NaN
# 904           muesli               NaN
# 905             milk               NaN
#
# [906 rows x 2 columns]

# %%
group = [0:906]
for i in group 
print ()

# %%
rng = np.random.default_rng()
x = rng.random (10)

# %%
print(x)
# Out:
# [0.40321508 0.62150461 0.92337403 0.24404661 0.90242731 0.96165383
#  0.6498202  0.5685309  0.02561278 0.02610454]

# %%
plt.hist(x)
plt.show()

# %%
df.iloc[1:11]
# Out:
#          FOOD NAME                 SCIENTIFIC NAME             GROUP  \
# 1    Savoy cabbage  Brassica oleracea var. sabauda        Vegetables
# 2    Silver linden                  Tilia argentea  Herbs and Spices
# 3             Kiwi             Actinidia chinensis            Fruits
# 4   Allium (Onion)                          Allium        Vegetables
# 5     Garden onion                     Allium cepa        Vegetables
# 6             Leek                   Allium porrum        Vegetables
# 7           Garlic                  Allium sativum  Herbs and Spices
# 8           Chives            Allium schoenoprasum  Herbs and Spices
# 9    Lemon verbena               Aloysia triphylla  Herbs and Spices
# 10      Cashew nut          Anacardium occidentale              Nuts
#
#                   SUB GROUP
# 1                  Cabbages
# 2                     Herbs
# 3           Tropical fruits
# 4   Onion-family vegetables
# 5   Onion-family vegetables
# 6   Onion-family vegetables
# 7                     Herbs
# 8                     Herbs
# 9                     Herbs
# 10                     Nuts

# %%
#List of all types of Herbs 
df.loc[df.loc[:,'SUB GROUP']=='Herbs']
# Out:
#               FOOD NAME                 SCIENTIFIC NAME             GROUP  \
# 0              Angelica                Angelica keiskei  Herbs and Spices
# 2         Silver linden                  Tilia argentea  Herbs and Spices
# 7                Garlic                  Allium sativum  Herbs and Spices
# 8                Chives            Allium schoenoprasum  Herbs and Spices
# 9         Lemon verbena               Aloysia triphylla  Herbs and Spices
# ..                  ...                             ...               ...
# 515     Tea leaf willow                   Salix pulchra  Herbs and Spices
# 564             Epazote          Dysphania ambrosioides  Herbs and Spices
# 570            Sourdock                   Rumex articus  Herbs and Spices
# 847    Yellow pond-lily                    Nuphar lutea  Herbs and Spices
# 863  Soft-necked garlic  Allium sativum L. var. sativum  Herbs and Spices
#
#     SUB GROUP
# 0       Herbs
# 2       Herbs
# 7       Herbs
# 8       Herbs
# 9       Herbs
# ..        ...
# 515     Herbs
# 564     Herbs
# 570     Herbs
# 847     Herbs
# 863     Herbs
#
# [61 rows x 4 columns]

# %%
df.loc[df.loc[:,'GROUP']=='Herbs and Spicies']
# Out:
# Empty DataFrame
# Columns: [FOOD NAME, SCIENTIFIC NAME, GROUP, SUB GROUP]
# Index: []

# %%
Resources:
    1. https://www.realsimple.com/food-recipes/shopping-storing/emergency-foods
    2. https://data.world/alexandra/generic-food-database/workspace/file?filename=generic-food.csv
