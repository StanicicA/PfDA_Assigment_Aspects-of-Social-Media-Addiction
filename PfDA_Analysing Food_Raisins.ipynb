# %% [markdown]
# # Analysing Food_Raisins

# %%
 #2 types of raisins being analysed using CSV File and the folowing
    
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ![Picture of Raisins](attachment:image-4.png)

# %%
#Imported CSV File for analysing Generic Food
pd.read_csv("Raisin_dataset.csv")
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter    Class
# 0    0.758651   1184.040  Kecimen
# 1    0.684130   1121.786  Kecimen
# ...

# %%
df = pd.read_csv("Raisin_dataset.csv")
# There are 4 columns in total: Name, Scientific name, Group, Sub-group. To see the quantity of each, see below
basicstat = (df.describe())
print (basicstat)
# Out:
#                 Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# count     900.000000       900.000000       900.000000    900.000000
# mean    87804.127778       430.929950       254.488133      0.781542
# std     39002.111390       116.035121        49.988902      0.090318
# min     25387.000000       225.629541       143.710872      0.348730
# 25%     59348.000000       345.442898       219.111126      0.741766
# 50%     78902.000000       407.803951       247.848409      0.798846
# 75%    105028.250000       494.187014       279.888575      0.842571
# max    235047.000000       997.291941       492.275279      0.962124
#
#           ConvexArea      Extent    Perimeter
# count     900.000000  900.000000   900.000000
# mean    91186.090000    0.699508  1165.906636
# std     40769.290132    0.053468   273.764315
# min     26139.000000    0.379856   619.074000
# 25%     61513.250000    0.670869   966.410750
# 50%     81651.000000    0.707367  1119.509000
# ...

# %%
df.head()
# Out:
#     Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  87524       442.246011       253.291155      0.819738       90546
# 1  75166       406.690687       243.032436      0.801805       78789
# 2  90856       442.267048       266.328318      0.798354       93717
# 3  45928       286.540559       208.760042      0.684989       47336
# 4  79408       352.190770       290.827533      0.564011       81463
#
#      Extent  Perimeter    Class
# 0  0.758651   1184.040  Kecimen
# 1  0.684130   1121.786  Kecimen
# 2  0.637613   1208.575  Kecimen
# 3  0.699599    844.162  Kecimen
# 4  0.792772   1073.251  Kecimen

# %%
df.mean()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_7984\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Area               87804.127778
# MajorAxisLength      430.929950
# MinorAxisLength      254.488133
# Eccentricity           0.781542
# ConvexArea         91186.090000
# Extent                 0.699508
# Perimeter           1165.906636
# dtype: float64

# %%
df.tail()
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter  Class
# 895  0.668793   1129.072  Besni
# 896  0.636476   1214.252  Besni
# 897  0.741099   1292.828  Besni
# 898  0.658798   1258.548  Besni
# 899  0.632020   1272.862  Besni

# %%
# Classification of the first 10 rows
df ['Class'][1:10]
# Out:
# 1    Kecimen
# 2    Kecimen
# 3    Kecimen
# 4    Kecimen
# 5    Kecimen
# 6    Kecimen
# 7    Kecimen
# 8    Kecimen
# 9    Kecimen
# Name: Class, dtype: object

# %%
#in more detail on the variables
info = df.info ()
print (info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             900 non-null    int64
#  1   MajorAxisLength  900 non-null    float64
#  2   MinorAxisLength  900 non-null    float64
#  3   Eccentricity     900 non-null    float64
#  4   ConvexArea       900 non-null    int64
#  5   Extent           900 non-null    float64
#  6   Perimeter        900 non-null    float64
#  7   Class            900 non-null    object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 56.4+ KB
# None

# %%
#first ten Kecimen Classes and Perimeters associated
df[['Class','Perimeter']][1:10]
# Out:
#      Class  Perimeter
# 1  Kecimen   1121.786
# 2  Kecimen   1208.575
# 3  Kecimen    844.162
# 4  Kecimen   1073.251
# 5  Kecimen    881.836
# 6  Kecimen    823.796
# 7  Kecimen    933.366
# 8  Kecimen    849.728
# 9  Kecimen    981.544

# %%
group = []
for i in list:
 if i == 'Class':
    print ("That is a snack!")
# Out:
# -----------------------------------------------------
# TypeError           Traceback (most recent call last)
# Input In [213], in <cell line: 2>()
#       1 group = []
# ----> 2 for i in list:
#       3  if i == 'Class':
#       4     print ("That is a snack!")
#
# TypeError: 'type' object is not iterable

# %%
plt.hist()
plt.show(df)
# Out:
# -----------------------------------------------------
# TypeError           Traceback (most recent call last)
# Input In [222], in <cell line: 1>()
# ----> 1 plt.hist()
#       2 plt.show(df)
#
# TypeError: hist() missing 1 required positional argument: 'x'

# %%
df.loc[1:11]
# Out:
#      Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 1   75166       406.690687       243.032436      0.801805       78789
# 2   90856       442.267048       266.328318      0.798354       93717
# 3   45928       286.540559       208.760042      0.684989       47336
# 4   79408       352.190770       290.827533      0.564011       81463
# 5   49242       318.125407       200.122120      0.777351       51368
# 6   42492       310.146072       176.131449      0.823099       43904
# 7   60952       332.455472       235.429835      0.706058       62329
# 8   42256       323.189607       172.575926      0.845499       44743
# 9   64380       366.964842       227.771615      0.784056       66125
# 10  80437       449.454581       232.325506      0.856043       84460
# 11  43725       301.322218       186.950629      0.784258       45021
#
#       Extent  Perimeter    Class
# 1   0.684130   1121.786  Kecimen
# 2   0.637613   1208.575  Kecimen
# ...

# %%
#List of all areas over 2000 000 
df.loc[df.loc[:,'Area']>= 200000]
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 487  210923       984.045491       367.279532      0.927737      278217
# 507  208264       675.098345       395.579291      0.810341      212813
# 516  202118       684.602958       379.719282      0.832080      209242
# 552  204864       596.639802       440.497127      0.674476      209457
# 580  206720       713.472549       373.642544      0.851905      210114
# 581  205497       632.727607       414.188326      0.755969      209486
# 668  206689       746.145341       355.300685      0.879347      212569
# 708  222915       731.559406       389.946700      0.846093      227170
# 711  204226       648.204288       402.283271      0.784118      207198
# 804  223075       694.247550       411.810369      0.805073      225916
# 812  235047       772.956877       388.201507      0.864735      239093
# 866  225043       740.003743       390.300858      0.849598      229195
# ...

# %%
#list of Kecimen class
df.loc[df.loc[:,'Class']=='Kecimen']
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 445  61200       323.174410       246.288324      0.647470       64553
# 446  87089       396.486857       280.245450      0.707392       88754
# 447  59589       383.571233       201.381855      0.851091       62974
# 448  50312       354.235551       182.312081      0.857392       52070
# 449  41995       259.208878       210.350798      0.584337       43443
#
#        Extent  Perimeter    Class
# 0    0.758651   1184.040  Kecimen
# 1    0.684130   1121.786  Kecimen
# ...

# %%
#pLotting using seaborn where we can obviously see that Besni as a Class is superior to Keciman
plt.show()
sns.pairplot(df,hue='Class')

# %% [markdown]
# Resources:
#     *
#     2.https://nutsandsnacks.com.sg/the-difference-between-raisins-sultanas-and-currants/
#     3.https://www.youtube.com/watch?v=OS2m0f2gVJ0&ab_channel=SoumilShah
#     4.https://archive.ics.uci.edu/ml/datasets/Raisin+Dataset
